# %%
import csv
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("chase_deposits_us.csv")

# %%
data.head(10)
# Out:
#       Institution Name  Main Office                           Branch Name  \
# 0  JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1  JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2  JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3  JPMorgan Chase Bank            0                North Hartsdale Branch
# 4  JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# 5  JPMorgan Chase Bank            0                   Mount Vernon Branch
# 6  JPMorgan Chase Bank            0                    Castle Hill Branch
# 7  JPMorgan Chase Bank            0                Burnside Avenue Branch
# 8  JPMorgan Chase Bank            0                       Gun Hill Branch
# 9  JPMorgan Chase Bank            0               Kingsbridge Road Branch
#
#    Branch Number Established Date Acquired Date            Street Address  \
# 0              0       01/01/1824           NaN      1111 Polaris Parkway
# ...

# %%
data.tail()
# Out:
#          Institution Name  Main Office                      Branch Name  \
# 5408  JPMorgan Chase Bank            0  Alameda and Compton Blvd Branch
# 5409  JPMorgan Chase Bank            0            Charleston and Rancho
# 5410  JPMorgan Chase Bank            0                Los Olivos Branch
# 5411  JPMorgan Chase Bank            0               Lake Forest Branch
# 5412  JPMorgan Chase Bank            0                Buffalo-Mm Branch
#
#       Branch Number Established Date Acquired Date            Street Address  \
# 5408           7981       11/03/2015           NaN        251 E Compton Blvd
# 5409           7982       02/02/2016           NaN   2311 W Chafrleston Blvd
# 5410           7984       03/15/2016           NaN  8593 Irvine Center Drive
# 5411           7988       01/01/2016           NaN            5660 Read Blvd
# 5412           7989       01/01/2016           NaN           350 Main Street
#
#              City       County State  Zipcode  Latitude  Longitude  \
# ...

# %%
data.shape
# Out:
# (5413, 20)

# %%
dfState = data.set_index("State")
dfState.head()
# Out:
#           Institution Name  Main Office                           Branch Name  \
# State
# OH     JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# NY     JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# NY     JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# NY     JPMorgan Chase Bank            0                North Hartsdale Branch
# NY     JPMorgan Chase Bank            0              Lawrence Rockaway Branch
#
#        Branch Number Established Date Acquired Date            Street Address  \
# State
# OH                 0       01/01/1824           NaN      1111 Polaris Parkway
# NY                 2       03/20/1961           NaN     676 White Plains Road
# NY                 3       09/09/1963           NaN    410 Northern Boulevard
# NY                 4       02/19/1966           NaN  353 North Central Avenue
# NY                 5       01/16/1965           NaN     335 Rockaway Turnpike
#
# ...

# %%
dfState.groupby("State").mean().head()
# Out:
#        Main Office  Branch Number       Zipcode   Latitude   Longitude  \
# State
# AZ             0.0    3633.179688  85398.687500  33.383542 -111.899391
# CA             0.0    5913.613161  92805.446660  35.336353 -119.409642
# CO             0.0    4774.482456  80312.236842  39.755065 -104.976522
# CT             0.0    3319.280000   6753.000000  41.187905  -73.375007
# DC             0.0    4409.000000  20006.000000  38.900240  -77.038070
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# AZ      75895.315574   77178.281124   83572.673228   91961.228346
# CA      83221.265363   82050.839793   82603.579191   85457.394036
# CO      69282.594059   81529.990566   80245.581818   95895.300885
# CT      88994.609756   91244.880952   92204.000000   96166.702128
# DC          0.000000       0.000000       0.000000       0.000000
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# State
# AZ      96719.066406  106869.234375  117683.320312
# ...

# %%
dfState.groupby("State").sum().head()
# Out:
#        Main Office  Branch Number   Zipcode     Latitude     Longitude  \
# State
# AZ               0         930094  21862064   8512.80314  -28534.34458
# CA               0        5931354  93083863  34629.62581 -117021.44869
# CO               0         544291   9155595   4532.07743  -11967.32348
# CT               0         165964    337650   1977.01942   -3522.00035
# DC               0           4409     20006     38.90024     -77.03807
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# AZ        18518457.0     19217392.0     21227459.0     23358152.0
# CA        59586426.0     63507350.0     71452096.0     80244493.0
# CO         6997542.0      8642179.0      8827014.0     10836169.0
# CT         3648779.0      3832285.0      4241384.0      4519835.0
# DC               0.0            0.0            0.0            0.0
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# State
# AZ        24760081.0     27358524.0       30126930
# ...

# %%
dfState1 = dfState.groupby("State").sum()
dfStateDeposits = dfState1.iloc[:, 5:]
dfStateDeposits.head()

#parameters for iloc:
#  1) first : means ALL rows
#  2) 5: means all columns after the 5th column
#   [:, 5:6] means ALL rows and columns 5 and 6
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# AZ        18518457.0     19217392.0     21227459.0     23358152.0
# CA        59586426.0     63507350.0     71452096.0     80244493.0
# CO         6997542.0      8642179.0      8827014.0     10836169.0
# CT         3648779.0      3832285.0      4241384.0      4519835.0
# DC               0.0            0.0            0.0            0.0
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# State
# AZ        24760081.0     27358524.0       30126930
# CA        91348811.0    102212009.0      118958728
# CO         9749824.0     10187131.0       11528794
# CT         4802183.0      5003594.0        5533022
# DC               0.0            0.0              0

# %%
dfStateDeposits.describe()
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   2.600000e+01   2.600000e+01   2.600000e+01   2.600000e+01
# mean    4.796397e+07   5.648664e+07   6.324907e+07   6.975289e+07
# std     1.350215e+08   1.598470e+08   1.789220e+08   1.963973e+08
# min     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%     1.601384e+06   1.581912e+06   1.700482e+06   1.871332e+06
# 50%     6.541136e+06   7.700594e+06   8.060074e+06   9.367626e+06
# 75%     1.728125e+07   1.790490e+07   1.970936e+07   2.204719e+07
# max     6.503506e+08   7.628337e+08   8.534400e+08   9.389485e+08
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# count   2.600000e+01   2.600000e+01   2.600000e+01
# mean    7.870365e+07   8.163962e+07   8.886039e+07
# std     2.202840e+08   2.279255e+08   2.476405e+08
# min     0.000000e+00   0.000000e+00   0.000000e+00
# 25%     2.203384e+06   2.558686e+06   3.598915e+06
# 50%     9.108016e+06   1.114782e+07   1.211900e+07
# ...

# %%
dfStateDeposits = dfStateDeposits.drop(['DC', 'MA', 'PA'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-92f6b65a86ce> in <module>()
# ----> 1 dfStateDeposits = dfStateDeposits.drop(['DC', 'MA', 'PA'])
#
# C:\programdata\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# C:\programdata\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
# ...

# %%
dfStateDeposits.head()
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# AZ        18518457.0     19217392.0     21227459.0     23358152.0
# CA        59586426.0     63507350.0     71452096.0     80244493.0
# CO         6997542.0      8642179.0      8827014.0     10836169.0
# CT         3648779.0      3832285.0      4241384.0      4519835.0
# FL         9708730.0     11568770.0     14901287.0     18114286.0
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# State
# AZ        24760081.0     27358524.0       30126930
# CA        91348811.0    102212009.0      118958728
# CO         9749824.0     10187131.0       11528794
# CT         4802183.0      5003594.0        5533022
# FL        21350108.0     24741660.0       28836780

# %%
dfStateDeposits.loc['CO']
# Out:
# 2010 Deposits     6997542.0
# 2011 Deposits     8642179.0
# 2012 Deposits     8827014.0
# 2013 Deposits    10836169.0
# 2014 Deposits     9749824.0
# 2015 Deposits    10187131.0
# 2016 Deposits    11528794.0
# Name: CO, dtype: float64

# %%
data[data.State == 'CO']
# Out:
#          Institution Name  Main Office  \
# 1825  JPMorgan Chase Bank            0
# 1826  JPMorgan Chase Bank            0
# 1827  JPMorgan Chase Bank            0
# 1828  JPMorgan Chase Bank            0
# 1829  JPMorgan Chase Bank            0
# 1830  JPMorgan Chase Bank            0
# 1831  JPMorgan Chase Bank            0
# 1832  JPMorgan Chase Bank            0
# 1833  JPMorgan Chase Bank            0
# 1834  JPMorgan Chase Bank            0
# 1835  JPMorgan Chase Bank            0
# 1836  JPMorgan Chase Bank            0
# 1837  JPMorgan Chase Bank            0
# 1838  JPMorgan Chase Bank            0
# 1839  JPMorgan Chase Bank            0
# 1840  JPMorgan Chase Bank            0
# 1841  JPMorgan Chase Bank            0
# 1842  JPMorgan Chase Bank            0
# 1843  JPMorgan Chase Bank            0
# 1844  JPMorgan Chase Bank            0
# 1845  JPMorgan Chase Bank            0
# 1846  JPMorgan Chase Bank            0
# 1847  JPMorgan Chase Bank            0
# ...

# %%
dfStateDeposits.sort_values('2010 Deposits', ascending=True)
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# ID          363738.0       362715.0       406383.0       427400.0
# GA          573701.0       833170.0      1235106.0      1657658.0
# NV          997680.0      1240156.0      1567441.0      1881342.0
# OK         1597965.0      1612901.0      1748042.0      1867995.0
# WV         1611641.0      1571582.0      1684628.0      1730910.0
# CT         3648779.0      3832285.0      4241384.0      4519835.0
# OR         4008214.0      4010326.0      4241729.0      4438372.0
# KY         4176387.0      4450080.0      5060968.0      4682846.0
# WI         5732417.0      6759009.0      7293133.0      7899084.0
# UT         6084730.0      6325245.0      3663922.0      4409290.0
# CO         6997542.0      8642179.0      8827014.0     10836169.0
# WA         9000546.0      9327661.0     10038882.0     10995788.0
# NJ         9532159.0     11112342.0     11877962.0     13824392.0
# ...

# %%
dfStateDeposits["rank_col"] = dfStateDeposits["2010 Deposits"].rank(ascending=True)

# %%
dfStateDeposits.head()
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# State
# AZ        18518457.0     19217392.0     21227459.0     23358152.0
# CA        59586426.0     63507350.0     71452096.0     80244493.0
# CO         6997542.0      8642179.0      8827014.0     10836169.0
# CT         3648779.0      3832285.0      4241384.0      4519835.0
# FL         9708730.0     11568770.0     14901287.0     18114286.0
#
#        2014 Deposits  2015 Deposits  2016 Deposits  rank_col
# State
# AZ        24760081.0     27358524.0       30126930      17.0
# CA        91348811.0    102212009.0      118958728      20.0
# CO         9749824.0     10187131.0       11528794      11.0
# CT         4802183.0      5003594.0        5533022       6.0
# FL        21350108.0     24741660.0       28836780      14.0

# %%
data['newEstablishedDate'] = pd.to_datetime(data["Established Date"])

# %%
data.head()
# Out:
#       Institution Name  Main Office                           Branch Name  \
# 0  JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1  JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2  JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3  JPMorgan Chase Bank            0                North Hartsdale Branch
# 4  JPMorgan Chase Bank            0              Lawrence Rockaway Branch
#
#    Branch Number Established Date Acquired Date            Street Address  \
# 0              0       01/01/1824           NaN      1111 Polaris Parkway
# 1              2       03/20/1961           NaN     676 White Plains Road
# 2              3       09/09/1963           NaN    410 Northern Boulevard
# 3              4       02/19/1966           NaN  353 North Central Avenue
# 4              5       01/16/1965           NaN     335 Rockaway Turnpike
#
# ...

# %%
dfDates = data.set_index("newEstablishedDate")

# %%
dfDates.head()
# Out:
#                        Institution Name  Main Office  \
# newEstablishedDate
# 1824-01-01          JPMorgan Chase Bank            1
# 1961-03-20          JPMorgan Chase Bank            0
# 1963-09-09          JPMorgan Chase Bank            0
# 1966-02-19          JPMorgan Chase Bank            0
# 1965-01-16          JPMorgan Chase Bank            0
#
#                                              Branch Name  Branch Number  \
# newEstablishedDate
# 1824-01-01               JPMorgan Chase Bank Main Office              0
# 1961-03-20                 Vernon Hills Scarsdale Branch              2
# 1963-09-09          Great Neck Northern Boulevard Branch              3
# 1966-02-19                        North Hartsdale Branch              4
# 1965-01-16                      Lawrence Rockaway Branch              5
#
#                    Established Date Acquired Date            Street Address  \
# newEstablishedDate
# ...

# %%
dfDates = dfDates.fillna(0)
dfDates.head()
# Out:
#                        Institution Name  Main Office  \
# newEstablishedDate
# 1824-01-01          JPMorgan Chase Bank            1
# 1961-03-20          JPMorgan Chase Bank            0
# 1963-09-09          JPMorgan Chase Bank            0
# 1966-02-19          JPMorgan Chase Bank            0
# 1965-01-16          JPMorgan Chase Bank            0
#
#                                              Branch Name  Branch Number  \
# newEstablishedDate
# 1824-01-01               JPMorgan Chase Bank Main Office              0
# 1961-03-20                 Vernon Hills Scarsdale Branch              2
# 1963-09-09          Great Neck Northern Boulevard Branch              3
# 1966-02-19                        North Hartsdale Branch              4
# 1965-01-16                      Lawrence Rockaway Branch              5
#
#                    Established Date Acquired Date            Street Address  \
# newEstablishedDate
# ...

# %%
dfDates.query("State == 'OH'")
# Out:
#                        Institution Name  Main Office  \
# newEstablishedDate
# 1824-01-01          JPMorgan Chase Bank            1
# 1958-06-09          JPMorgan Chase Bank            0
# 1964-07-06          JPMorgan Chase Bank            0
# 1959-11-16          JPMorgan Chase Bank            0
# 1955-06-20          JPMorgan Chase Bank            0
# 1963-09-03          JPMorgan Chase Bank            0
# 1963-04-01          JPMorgan Chase Bank            0
# 1964-06-25          JPMorgan Chase Bank            0
# 1956-06-04          JPMorgan Chase Bank            0
# 1966-05-16          JPMorgan Chase Bank            0
# 1968-02-05          JPMorgan Chase Bank            0
# 1968-12-16          JPMorgan Chase Bank            0
# 1970-06-01          JPMorgan Chase Bank            0
# 1970-12-14          JPMorgan Chase Bank            0
# 1972-01-24          JPMorgan Chase Bank            0
# 1972-10-30          JPMorgan Chase Bank            0
# ...

# %%
dfDates.dropna().describe()
# Out:
#        Main Office  Branch Number       Zipcode     Latitude    Longitude  \
# count  5413.000000    5413.000000   5413.000000  5413.000000  5413.000000
# mean      0.000185    4303.761685  58800.016072    36.794751   -94.045423
# std       0.013592    2146.930304  30863.015686     6.770792    20.326423
# min       0.000000       0.000000   2110.000000     0.000000  -124.421370
# 25%       0.000000    2548.000000  33334.000000    33.115910  -115.061950
# 50%       0.000000    4274.000000  60654.000000    38.662810   -88.293020
# 75%       0.000000    6172.000000  89102.000000    41.032010   -81.270380
# max       1.000000    7989.000000  99362.000000    48.844760     0.000000
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   5.413000e+03   5.413000e+03   5.413000e+03   5.413000e+03
# mean    2.303830e+05   2.713195e+05   3.038012e+05   3.350407e+05
# std     8.891009e+06   1.049878e+07   1.173968e+07   1.290943e+07
# ...
