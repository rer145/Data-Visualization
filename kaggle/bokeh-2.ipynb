# %% [markdown]
# https://www.kaggle.com/kanncaa1/interactive-bokeh-tutorial-part-2

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_file, show, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, CategoricalColorMapper
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a1b417ec-28b8-4136-bf4a-b269e90488a4">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('vgsales.csv')
data.dropna(how="any", inplace=True)
data.Year = data.Year.astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16291 non-null int64
# Name            16291 non-null object
# Platform        16291 non-null object
# Year            16291 non-null int32
# Genre           16291 non-null object
# Publisher       16291 non-null object
# NA_Sales        16291 non-null float64
# EU_Sales        16291 non-null float64
# JP_Sales        16291 non-null float64
# Other_Sales     16291 non-null float64
# Global_Sales    16291 non-null float64
# dtypes: float64(5), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
from IPython.html.widgets import interact
data = data.set_index("Year")
x = data.loc[1980].EU_Sales
y = data.loc[1980].Global_Sales
output_notebook()
# Out:
# C:\programdata\anaconda3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="81ce41a2-3ff6-455e-8a76-82df94bc413c">Loading BokehJS ...</span>
#     </div>

# %%
source = ColumnDataSource(data={
    "x": data.loc[1980].EU_Sales,
    "y": data.loc[1980].Global_Sales,
    "Genre": data.loc[1980].Genre,
    "Publisher": data.loc[1980].Publisher,
    "Platformat": data.loc[1980].Platform
})

factors = data.Genre.unique().tolist()
colors = ["red", 'green', 'blue', 'black', 'orange', 'brown', 'grey', 'purple', 'yellow', 'white', 'pink', 'peru']
color_mapper = CategoricalColorMapper(factors=factors, palette=colors)

hover = HoverTool(tooltips=[("Genre of game", "@Genre"), ("Publisher of game", "@Publisher"), 
                           ("Platform of game", "@Platform")])

plot = figure(title="Video Game Sames", tools=[hover, "crosshair", "pan", "box_zoom"])
plot.circle(x, y, source=source, color=dict(field="Genre", transform=color_mapper), 
           legend="Genre", hover_color="red")

def update(x_axis, y_axis, year=1980):
    c1 = x_axis
    c2 = y_axis
    new_data = {
        'x': data.loc[year, c1],
        'y': data.loc[year, c2],
        'Genre': data.loc[year].Genre,
        'Publisher': data.loc[year].Publisher,
        'Platform': data.loc[year].Platform
    }
    source.data = new_data
    plot.xaxis.axis_label = c1
    plot.yaxis.axis_label = c2
    push_notebook()
    
show(plot, notebook_handle=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-c4acb28b9282> in <module>()
#      16 plot = figure(title="Video Game Sames", tools=[hover, "crosshair", "pan", "box_zoom"])
#      17 plot.circle(x, y, source=source, color=dict(field="Genre", transform=color_mapper),
# ---> 18            legend="Genre", hover_color="red")
#      19
#      20 def update(x_axis, y_axis, year=1980):
#
# fakesource in circle(self, x, y, **kwargs)
#
# C:\programdata\anaconda3\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     718         # handle the main glyph, need to process literals
#     719         glyph_ca = _pop_colors_and_alpha(glyphclass, kwargs)
# --> 720         _process_sequence_literals(glyphclass, kwargs, source, is_user_source)
#     721         _process_sequence_literals(glyphclass, glyph_ca, source, is_user_source)
#     722
#
# ...
