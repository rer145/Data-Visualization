# %%
import pandas as pd

# %%
data2016 = pd.read_csv('rround-2016.txt', sep=';', low_memory=False, encoding='latin-1')
data2017 = pd.read_csv('rround-2017.txt', sep=';', low_memory=False, encoding='latin-1')

# %%
data2016.head()
# Out:
#   Tour  Tournament Year  Tournament #  Permanent Tournament #  Course #  \
# 0    R             2016            10                     464       552
# 1    R             2016            10                     464       552
# 2    R             2016            10                     464       552
# 3    R             2016            10                     464       552
# 4    R             2016            10                     464       552
#
#   Team ID  Team Number  Player Number      Player Name  Round Number  \
# 0                    0           2206      Toms, David             1
# 1                    0           8075     Kelly, Jerry             1
# 2                    0          10213     Pride, Dicky             1
# 3                    0          10505   Bertsch, Shane             1
# 4                    0          10860  Leonard, Justin             1
#
#       ...      Putting   > 10' (putts made) Putting   > 10' (attempts)  \
# 0     ...                               1.0                       14.0
# 1     ...                               2.0                       14.0
# 2     ...                               1.0                       14.0
# 3     ...                               3.0                       11.0
# 4     ...                               1.0                       12.0
#
#    Putting   > 10' (rank)  Total Putts Gained Total SG T2G  Total SG Total  \
# 0                   116.0               .992-         .736           .257-
# 1                    69.0               2.019       3.276-          1.257-
# 2                   116.0               .400-       1.856-          2.257-
# 3                    21.0                .476        .733-           .257-
# 4                   108.0                .960       2.217-          1.257-
#
#    OTT SG Avg. APP SG Avg.  ARG SG Avg. Unnamed: 178
# 0        .245-        .715         .266          NaN
# 1        .251-      2.735-        .288-          NaN
# 2       1.522-        .507        .840-          NaN
# 3         .101      1.383-         .549          NaN
# 4        .160-      1.919-        .136-          NaN
#
# [5 rows x 179 columns]

# %%
data2017.head()
# Out:
#   Tour  Tournament Year  Tournament #  Permanent Tournament #  Course #  \
# 0    R             2017            10                     464       552
# 1    R             2017            10                     464       552
# 2    R             2017            10                     464       552
# 3    R             2017            10                     464       552
# 4    R             2017            10                     464       552
#
#   Team ID  Team Number  Player Number       Player Name  Round Number  \
# 0                    0           1810   Mickelson, Phil             1
# 1                    0           2206       Toms, David             1
# 2                    0          12510    Campbell, Chad             1
# 3                    0          12716  Hoffman, Charley             1
# 4                    0          19803      Armour, Ryan             1
#
#       ...      Putting   > 10' (putts made) Putting   > 10' (attempts)  \
# 0     ...                               1.0                        9.0
# 1     ...                               3.0                       11.0
# 2     ...                               NaN                        8.0
# 3     ...                               4.0                       14.0
# 4     ...                               4.0                       15.0
#
#    Putting   > 10' (rank)  Total Putts Gained Total SG T2G  Total SG Total  \
# 0                    93.0               .510-        2.573           2.063
# 1                    24.0               1.945       4.884-          2.938-
# 2                   127.0              1.357-        2.420           1.063
# 3                    18.0               2.784        .722-           2.063
# 4                    31.0               2.062       3.001-           .938-
#
#    OTT SG Avg. APP SG Avg.  ARG SG Avg. Unnamed: 178
# 0        .368-       2.150         .790          NaN
# 1        .325-      3.588-        .969-          NaN
# 2        .432-       1.957         .894          NaN
# 3        1.542       .961-       1.303-          NaN
# 4       1.306-      1.668-        .025-          NaN
#
# [5 rows x 179 columns]

# %%
data2016.describe()
# Out:
#        Tournament Year  Tournament #  Permanent Tournament #      Course #  \
# count          18273.0  18273.000000            18273.000000  18273.000000
# mean            2016.0    253.308707              161.944125    462.968150
# std                0.0    139.377791              211.163605    308.426508
# min             2016.0     10.000000                2.000000      4.000000
# 25%             2016.0    140.000000               13.000000     32.000000
# 50%             2016.0    260.000000               30.000000    608.000000
# 75%             2016.0    360.000000              470.000000    715.000000
# max             2016.0    500.000000              518.000000    819.000000
#
#         Team Number  Player Number  Round Number    Course Par  \
# count  18273.000000   18273.000000  18273.000000  18273.000000
# mean       0.692607   28104.296722      2.222405     71.197559
# std        7.174162    7976.365884      1.078623      0.829117
# min        0.000000    1116.000000      1.000000     70.000000
# 25%        0.000000   24494.000000      1.000000     70.000000
# 50%        0.000000   28114.000000      2.000000     71.000000
# 75%        0.000000   33141.000000      3.000000     72.000000
# max      112.000000   50844.000000      7.000000     73.000000
#
#        Course Yardage   Round Score      ...       Putting 20'-25'(attempts)  \
# count    18273.000000  18273.000000      ...                    18273.000000
# mean      7270.281891     70.905544      ...                        1.141247
# std        192.081649      4.652863      ...                        1.210054
# min       6816.000000      0.000000      ...                        0.000000
# 25%       7140.000000     69.000000      ...                        0.000000
# 50%       7261.000000     71.000000      ...                        1.000000
# 75%       7428.000000     73.000000      ...                        2.000000
# max       7698.000000     89.000000      ...                        9.000000
#
#        Putting 20'-25'(putts made)  Putting 20'-25'(rank)  \
# count                 18273.000000           10971.000000
# mean                      0.135446              16.681889
# std                       0.370764               8.802439
# min                       0.000000               1.000000
# 25%                       0.000000              10.000000
# 50%                       0.000000              17.000000
# 75%                       0.000000              24.000000
# max                       3.000000              38.000000
#
#        Putting >25'(attempts)  Putting   >25'(putts made)  \
# count            18273.000000                18273.000000
# mean                 3.331746                    0.174410
# std                  2.483670                    0.427617
# min                  0.000000                    0.000000
# 25%                  1.000000                    0.000000
# 50%                  4.000000                    0.000000
# 75%                  5.000000                    0.000000
# max                 12.000000                    4.000000
#
#        Putting   >25'(rank)  Putting   > 10' (putts made)  \
# count          13853.000000                  11287.000000
# mean              20.525879                      1.941703
# std                9.978319                      1.026308
# min                1.000000                      1.000000
# 25%               13.000000                      1.000000
# 50%               21.000000                      2.000000
# 75%               27.000000                      2.000000
# max               46.000000                      7.000000
#
#        Putting   > 10' (attempts)  Putting   > 10' (rank)  Unnamed: 178
# count                13985.000000            13985.000000           0.0
# mean                    10.517769               51.824383           NaN
# std                      2.232737               35.388954           NaN
# min                      2.000000                1.000000           NaN
# 25%                      9.000000               23.000000           NaN
# 50%                     11.000000               46.000000           NaN
# 75%                     12.000000               74.000000           NaN
# max                     18.000000              135.000000           NaN
#
# [8 rows x 157 columns]

# %%
data2016.loc[(data2016['Player Name'] == 'Thomas, Justin')].describe()
# Out:
#        Tournament Year  Tournament #  Permanent Tournament #    Course #  \
# count             99.0     99.000000               99.000000   99.000000
# mean            2016.0    265.454545              205.272727  458.181818
# std                0.0    152.852288              223.519520  303.321254
# min             2016.0     10.000000                3.000000    6.000000
# 25%             2016.0    160.000000               14.000000   36.000000
# 50%             2016.0    250.000000               34.000000  552.000000
# 75%             2016.0    400.000000              473.000000  704.500000
# max             2016.0    500.000000              505.000000  800.000000
#
#        Team Number  Player Number  Round Number  Course Par  Course Yardage  \
# count    99.000000           99.0     99.000000   99.000000       99.000000
# mean      1.606061        33448.0      2.363636   71.101010     7282.242424
# std      10.645319            0.0      1.110750    0.897786      193.968180
# min       0.000000        33448.0      1.000000   70.000000     6841.000000
# 25%       0.000000        33448.0      1.000000   70.000000     7140.000000
# 50%       0.000000        33448.0      2.000000   71.000000     7297.000000
# 75%       0.000000        33448.0      3.000000   72.000000     7435.000000
# max      95.000000        33448.0      4.000000   73.000000     7575.000000
#
#        Round Score      ...       Putting 20'-25'(attempts)  \
# count    99.000000      ...                       99.000000
# mean     70.646465      ...                        1.181818
# std       3.479717      ...                        1.327601
# min      61.000000      ...                        0.000000
# 25%      69.000000      ...                        0.000000
# 50%      70.000000      ...                        1.000000
# 75%      73.000000      ...                        2.000000
# max      82.000000      ...                        5.000000
#
#        Putting 20'-25'(putts made)  Putting 20'-25'(rank)  \
# count                    99.000000              57.000000
# mean                      0.121212              14.491228
# std                       0.328035               7.755465
# min                       0.000000               1.000000
# 25%                       0.000000              10.000000
# 50%                       0.000000              14.000000
# 75%                       0.000000              20.000000
# max                       1.000000              29.000000
#
#        Putting >25'(attempts)  Putting   >25'(putts made)  \
# count               99.000000                   99.000000
# mean                 3.101010                    0.131313
# std                  2.332096                    0.339461
# min                  0.000000                    0.000000
# 25%                  0.500000                    0.000000
# 50%                  3.000000                    0.000000
# 75%                  5.000000                    0.000000
# max                  8.000000                    1.000000
#
#        Putting   >25'(rank)  Putting   > 10' (putts made)  \
# count             74.000000                     61.000000
# mean              19.054054                      1.803279
# std                9.875793                      0.927715
# min                1.000000                      1.000000
# 25%               12.000000                      1.000000
# 50%               18.500000                      2.000000
# 75%               24.750000                      2.000000
# max               46.000000                      5.000000
#
#        Putting   > 10' (attempts)  Putting   > 10' (rank)  Unnamed: 178
# count                   75.000000               75.000000           0.0
# mean                    10.746667               47.546667           NaN
# std                      2.047367               32.668810           NaN
# min                      6.000000                1.000000           NaN
# 25%                      9.000000               23.000000           NaN
# 50%                     11.000000               43.000000           NaN
# 75%                     12.000000               63.500000           NaN
# max                     15.000000              131.000000           NaN
#
# [8 rows x 157 columns]

# %%
jt2016 = data2016.loc[(data2016['Player Name'] == 'Thomas, Justin')]
jt2017 = data2017.loc[(data2017['Player Name'] == 'Thomas, Justin')]

# %%
jt2016["Round Score"].describe()
# Out:
# count    99.000000
# mean     70.646465
# std       3.479717
# min      61.000000
# 25%      69.000000
# 50%      70.000000
# 75%      73.000000
# max      82.000000
# Name: Round Score, dtype: float64

# %%
jt2017['Round Score'].describe()
# Out:
# count    86.000000
# mean     68.558140
# std       5.844262
# min      36.000000
# 25%      67.000000
# 50%      69.000000
# 75%      71.000000
# max      80.000000
# Name: Round Score, dtype: float64

# %%
jt2017 = jt2017[(jt2017["Round Score"] >= 58)]
jt2017.loc[(jt2017["Round Score"] <= 58)]
# Out:
# Empty DataFrame
# Columns: [Tour, Tournament Year, Tournament #, Permanent Tournament #, Course #, Team ID, Team Number, Player Number, Player Name, Round Number, Event Name, Course Name, Course Par, Course Yardage, Tee Time, Round Score, End of Round Finish Pos. (numeric), End of Round Finish Pos. (text),  End of Event Pos. (numeric), End of Event Pos. (text), In Playoff, Eagles, Eagles(Rank), Birdies, Birdies (Rank), Pars, Bogeys, Bogeys (Rank), Doubles, Others, Total Holes Over Par,  Bogey Avoidance Rank, Longest Drive, Longest Drives(Rank), Driving Distance(Total Distance), Driving Distance(Total Drives), Driving Distance(Rank), Driving Dist. - All Drives(Tot. Dist.), Driving Dist. - All Drives(# of Drives), Driving Dist. - All Drives(Rank), Drives Over 300 Yards (# of Drives), Driving Acc. %(Fairways Hit), Driving Acc. %(Possible Fairways), Driving Accuracy Rank, Left Rough Tendency(Total Left Rough), Right Rough Tendency(Total Right Rough), App. 50-75 yds(ft), App. 50-75 yds(attempts), App. 75-100 yds(ft), App. 75-100 yds(attempts), App. 100-125 yds(ft), App. 100-125 yds(attempts), Approaches 50-125 Yards(ft), Approaches 50-125 Yards(attempts), Approaches 125-150 Yards(ft), Approaches 125-150 Yards(attempts), Approaches 150-175 Yards(ft), Approaches 150-175 Yards(attempts), Approaches 175-200 Yards(ft), Approaches   175-200 Yards(attempts), Approaches >200 Yards(ft), Approaches >200 Yards(attempts), App. 50-75 yds(ft) - Rough, App. 50-75 yds(attempts) - Rough, App. 75-100 yds(ft) - Rough, App. 75-100 yds(attempts) - Rough, App. 100-125 yds(ft) - Rough, App. 100-125 yds(attempts) - Rough, Approaches 50-125 Yards(ft) - Rough, Approaches 50-125 Yards(attempts) - Rough, Approaches 125-150 Yards(ft) - Rough, Approaches 125-150 Yards(attempts) - Rough, Approaches 150-175 Yards(ft) - Rough, Approaches 150-175 Yards(attempts) - Rough, Approaches 175-200 Yards(ft) - Rough, Approaches 175-200 Yards(attempts) - Rough, Approaches >200 Yards(ft) - Rough, Approaches >200 Yards(attempts) - Rough, Total Holes Played, Total Greens in Regulation, GIR Rank, Total Distance(ft) Prox to Hole,  # of Attempts Prox to Hole, Proximity to Hole (Rank), Fairway Prox(attempts), Fairway Prox(distance in ft), Fairway Prox (Rank), Rough Prox(attempts), Rough Prox(distance in ft), Rough Prox (Rank), Left Rough Prox(attempts), Left Rough Prox(distance in ft), Right Rough Prox(attempts), Right Rough Prox(distance in ft), Going for Green(attempts), Going for Green(non-attempts), Going for the Green(successes), Scrambling Par or Better, Scrambling Missed GIR, Scrambling (Rank), ...]
# Index: []
#
# [0 rows x 179 columns]

# %%
jt2017["Round Score"].describe()
# Out:
# count    84.000000
# mean     69.250000
# std       3.721883
# min      59.000000
# 25%      67.000000
# 50%      69.000000
# 75%      71.000000
# max      80.000000
# Name: Round Score, dtype: float64

# %%
jt2017majors = jt2017[(jt2017["Event Name"] == "Masters Tournament") |
                    (jt2017["Event Name"] == "U.S. Open") |
                     (jt2017["Event Name"] == "The Open Championship") |
                     (jt2017["Event Name"] == "PGA Championship")]
jt2017majors.describe()
# Out:
#        Tournament Year  Tournament #  Permanent Tournament #    Course #  \
# count             14.0     14.000000               14.000000   14.000000
# mean            2017.0    358.571429               35.142857  217.571429
# std                0.0     81.416039               28.492528  170.639392
# min             2017.0    250.000000               14.000000   14.000000
# 25%             2017.0    275.000000               17.000000   69.500000
# 50%             2017.0    350.000000               26.000000  236.000000
# 75%             2017.0    440.000000               33.000000  241.000000
# max             2017.0    450.000000              100.000000  541.000000
#
#        Team Number  Player Number  Round Number  Course Par  Course Yardage  \
# count         14.0           14.0     14.000000   14.000000       14.000000
# mean           0.0        33448.0      2.357143   71.428571     7529.714286
# std            0.0            0.0      1.150728    0.755929      198.752815
# min            0.0        33448.0      1.000000   70.000000     7156.000000
# 25%            0.0        33448.0      1.250000   71.000000     7435.000000
# 50%            0.0        33448.0      2.000000   72.000000     7600.000000
# 75%            0.0        33448.0      3.000000   72.000000     7705.750000
# max            0.0        33448.0      4.000000   72.000000     7741.000000
#
#        Round Score      ...       Putting 20'-25'(attempts)  \
# count    14.000000      ...                       14.000000
# mean     70.928571      ...                        0.642857
# std       4.445642      ...                        1.008208
# min      63.000000      ...                        0.000000
# 25%      68.250000      ...                        0.000000
# 50%      70.500000      ...                        0.000000
# 75%      73.000000      ...                        1.000000
# max      80.000000      ...                        3.000000
#
#        Putting 20'-25'(putts made)  Putting 20'-25'(rank)  \
# count                    14.000000               5.000000
# mean                      0.142857              12.400000
# std                       0.363137              11.013628
# min                       0.000000               1.000000
# 25%                       0.000000               6.000000
# 50%                       0.000000              11.000000
# 75%                       0.000000              14.000000
# max                       1.000000              30.000000
#
#        Putting >25'(attempts)  Putting   >25'(putts made)  \
# count               14.000000                   14.000000
# mean                 2.071429                    0.285714
# std                  2.786348                    0.468807
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.500000                    0.000000
# 75%                  3.000000                    0.750000
# max                  8.000000                    1.000000
#
#        Putting   >25'(rank)  Putting   > 10' (putts made)  \
# count              7.000000                      7.000000
# mean              10.714286                      2.857143
# std                9.707631                      1.214986
# min                1.000000                      1.000000
# 25%                2.500000                      2.000000
# 50%                9.000000                      3.000000
# 75%               16.500000                      4.000000
# max               27.000000                      4.000000
#
#        Putting   > 10' (attempts)  Putting   > 10' (rank)  Unnamed: 178
# count                    8.000000                8.000000           0.0
# mean                     9.375000               28.000000           NaN
# std                      1.995531               46.488094           NaN
# min                      7.000000                1.000000           NaN
# 25%                      8.500000                2.500000           NaN
# 50%                      9.000000                9.500000           NaN
# 75%                     10.250000               25.500000           NaN
# max                     13.000000              138.000000           NaN
#
# [8 rows x 156 columns]

# %%
jt2016majors = jt2016[(jt2016["Event Name"] == "Masters Tournament") |
                    (jt2016["Event Name"] == "U.S. Open") |
                     (jt2016["Event Name"] == "The Open Championship") |
                     (jt2016["Event Name"] == "PGA Championship")]
jt2016majors.describe()
# Out:
#        Tournament Year  Tournament #  Permanent Tournament #    Course #  \
# count             16.0     16.000000               16.000000   16.000000
# mean            2016.0    350.000000               43.250000  511.500000
# std                0.0     72.295689               34.559128  299.883088
# min             2016.0    240.000000               14.000000   14.000000
# 25%             2016.0    315.000000               23.000000  459.500000
# 50%             2016.0    370.000000               29.500000  658.500000
# 75%             2016.0    405.000000               49.750000  710.500000
# max             2016.0    420.000000              100.000000  715.000000
#
#        Team Number  Player Number  Round Number  Course Par  Course Yardage  \
# count         16.0           16.0     16.000000   16.000000       16.000000
# mean           0.0        33448.0      2.500000   70.750000     7318.000000
# std            0.0            0.0      1.154701    0.856349      117.727369
# min            0.0        33448.0      1.000000   70.000000     7190.000000
# 25%            0.0        33448.0      1.750000   70.000000     7211.750000
# 50%            0.0        33448.0      2.500000   70.500000     7323.500000
# 75%            0.0        33448.0      3.250000   71.250000     7429.750000
# max            0.0        33448.0      4.000000   72.000000     7435.000000
#
#        Round Score      ...       Putting 20'-25'(attempts)  \
# count    16.000000      ...                       16.000000
# mean     72.437500      ...                        0.375000
# std       3.010399      ...                        0.885061
# min      67.000000      ...                        0.000000
# 25%      70.500000      ...                        0.000000
# 50%      73.000000      ...                        0.000000
# 75%      73.250000      ...                        0.000000
# max      78.000000      ...                        3.000000
#
#        Putting 20'-25'(putts made)  Putting 20'-25'(rank)  \
# count                         16.0               3.000000
# mean                           0.0              21.000000
# std                            0.0               1.732051
# min                            0.0              20.000000
# 25%                            0.0              20.000000
# 50%                            0.0              20.000000
# 75%                            0.0              21.500000
# max                            0.0              23.000000
#
#        Putting >25'(attempts)  Putting   >25'(putts made)  \
# count               16.000000                     16.0000
# mean                 1.312500                      0.0625
# std                  2.441823                      0.2500
# min                  0.000000                      0.0000
# 25%                  0.000000                      0.0000
# 50%                  0.000000                      0.0000
# 75%                  0.750000                      0.0000
# max                  6.000000                      1.0000
#
#        Putting   >25'(rank)  Putting   > 10' (putts made)  \
# count              4.000000                      2.000000
# mean              28.250000                      1.500000
# std               16.214705                      0.707107
# min                8.000000                      1.000000
# 25%               20.000000                      1.250000
# 50%               29.500000                      1.500000
# 75%               37.750000                      1.750000
# max               46.000000                      2.000000
#
#        Putting   > 10' (attempts)  Putting   > 10' (rank)  Unnamed: 178
# count                    4.000000                4.000000           0.0
# mean                    12.250000               77.750000           NaN
# std                      2.061553               37.294995           NaN
# min                     10.000000               46.000000           NaN
# 25%                     11.500000               56.500000           NaN
# 50%                     12.000000               67.000000           NaN
# 75%                     12.750000               88.250000           NaN
# max                     15.000000              131.000000           NaN
#
# [8 rows x 157 columns]

# %%
# compare tee time start with round score
# short game analysis
# off the tee analysis
# putting analysis

# %%
jt2017['TeeTimeHour'] = 0
jt2016['TeeTimeHour'] = 0
jt2017['TeeTimeHour'] = jt2017['Tee Time'].str[0:2]
jt2016['TeeTimeHour'] = jt2016['Tee Time'].str[0:2]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
jt2017['TeeTimeHour'] = jt2017['TeeTimeHour'].astype(int)
jt2016['TeeTimeHour'] = jt2016['TeeTimeHour'].astype(int)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jt2017['TeeTimeHour'].head()
# Out:
# 95      7
# 239    12
# 330    12
# 400    10
# 482     9
# Name: TeeTimeHour, dtype: int64

# %%
jt2017['TeeTimeHour'].describe()
# Out:
# count    84.000000
# mean     10.988095
# std       2.219812
# min       7.000000
# 25%       9.000000
# 50%      11.500000
# 75%      13.000000
# max      17.000000
# Name: TeeTimeHour, dtype: float64

# %%
jt2016['TeeTimeHour'].describe()
# Out:
# count    99.000000
# mean     10.676768
# std       2.298306
# min       7.000000
# 25%       9.000000
# 50%      11.000000
# 75%      13.000000
# max      17.000000
# Name: TeeTimeHour, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
jt2017.groupby(['TeeTimeHour'])['TeeTimeHour'].count()
# Out:
# TeeTimeHour
# 7      5
# 8     11
# 9     10
# 10     7
# 11     9
# 12    14
# 13    22
# 14     5
# 17     1
# Name: TeeTimeHour, dtype: int64

# %%
agg = jt2017.groupby(['TeeTimeHour'])['TeeTimeHour'].count()
agg.plot.bar()

# %%
agg = jt2017.groupby(['TeeTimeHour'])['Round Score'].mean()
agg.plot.bar()

# %%
agg = jt2016.groupby(['TeeTimeHour'])['Round Score'].mean()
agg.plot.bar()

# %%
fig = plt.figure()
plt.plot(jt2016.groupby(['TeeTimeHour'])['Round Score'].mean(), label='2016')
plt.plot(jt2017.groupby(['TeeTimeHour'])['Round Score'].mean(), label='2017')
plt.legend()
plt.show()

# %%
jt = pd.concat([jt2016, jt2017])
jt.head()
# Out:
#     Tour  Tournament Year  Tournament #  Permanent Tournament #  Course #  \
# 109    R             2016            10                     464       552
# 251    R             2016            10                     464       552
# 351    R             2016            10                     464       552
# 425    R             2016            10                     464       552
# 938    R             2016            30                     494       800
#
#     Team ID  Team Number  Player Number     Player Name  Round Number  \
# 109                    0          33448  Thomas, Justin             1
# 251                    0          33448  Thomas, Justin             2
# 351                    0          33448  Thomas, Justin             3
# 425                    0          33448  Thomas, Justin             4
# 938                    0          33448  Thomas, Justin             1
#
#         ...     Putting   > 10' (attempts) Putting   > 10' (rank)  \
# 109     ...                           12.0                  108.0
# 251     ...                            9.0                   80.0
# 351     ...                           11.0                   41.0
# 425     ...                           13.0                   36.0
# 938     ...                            NaN                    NaN
#
#      Total Putts Gained  Total SG T2G Total SG Total  OTT SG Avg.  \
# 109                .603         4.140          4.743        1.873
# 251               .159-         2.004          1.845        .749-
# 351               1.712         .797-           .915        1.182
# 425                .728         1.997          2.726         .480
# 938                .000          .000           .000         .000
#
#      APP SG Avg. ARG SG Avg.  Unnamed: 178 TeeTimeHour
# 109        1.479        .787           NaN           8
# 251        3.139       .384-           NaN          13
# 351       1.676-       .303-           NaN          11
# 425        1.783       .266-           NaN          12
# 938         .000        .000           NaN           8
#
# [5 rows x 180 columns]

# %%
jt.describe()
# Out:
#        Tournament Year  Tournament #  Permanent Tournament #    Course #  \
# count       183.000000    183.000000              183.000000  183.000000
# mean       2016.459016    270.218579              199.732240  435.497268
# std           0.499685    156.331418              222.317908  296.606945
# min        2016.000000     10.000000                3.000000    6.000000
# 25%        2016.000000    155.000000               16.000000   36.000000
# 50%        2016.000000    250.000000               33.000000  527.000000
# 75%        2017.000000    420.000000              473.000000  700.000000
# max        2017.000000    500.000000              505.000000  800.000000
#
#        Team Number  Player Number  Round Number  Course Par  Course Yardage  \
# count   183.000000          183.0    183.000000  183.000000      183.000000
# mean      3.967213        33448.0      2.338798   71.125683     7289.306011
# std      24.377728            0.0      1.101933    0.895990      190.414251
# min       0.000000        33448.0      1.000000   70.000000     6841.000000
# 25%       0.000000        33448.0      1.000000   70.000000     7161.000000
# 50%       0.000000        33448.0      2.000000   71.000000     7322.000000
# 75%       0.000000        33448.0      3.000000   72.000000     7426.500000
# max     215.000000        33448.0      4.000000   73.000000     7741.000000
#
#        Round Score     ...       Putting 20'-25'(putts made)  \
# count   183.000000     ...                        183.000000
# mean     70.005464     ...                          0.131148
# std       3.650225     ...                          0.354349
# min      59.000000     ...                          0.000000
# 25%      68.000000     ...                          0.000000
# 50%      70.000000     ...                          0.000000
# 75%      72.000000     ...                          0.000000
# max      82.000000     ...                          2.000000
#
#        Putting 20'-25'(rank)  Putting >25'(attempts)  \
# count             104.000000              183.000000
# mean               14.201923                2.983607
# std                 8.237235                2.312117
# min                 1.000000                0.000000
# 25%                 7.000000                0.000000
# 50%                13.000000                3.000000
# 75%                20.000000                5.000000
# max                34.000000                8.000000
#
#        Putting   >25'(putts made)  Putting   >25'(rank)  \
# count                  183.000000            136.000000
# mean                     0.158470             17.977941
# std                      0.408726             10.112308
# min                      0.000000              1.000000
# 25%                      0.000000             10.000000
# 50%                      0.000000             18.000000
# 75%                      0.000000             25.000000
# max                      3.000000             46.000000
#
#        Putting   > 10' (putts made)  Putting   > 10' (attempts)  \
# count                    118.000000                  140.000000
# mean                       2.008475                   10.357143
# std                        1.041824                    2.088238
# min                        1.000000                    5.000000
# 25%                        1.000000                    9.000000
# 50%                        2.000000                   10.500000
# 75%                        2.750000                   12.000000
# max                        5.000000                   15.000000
#
#        Putting   > 10' (rank)  Unnamed: 178  TeeTimeHour
# count              140.000000           0.0   183.000000
# mean                40.392857           NaN    10.819672
# std                 32.605931           NaN     2.261781
# min                  1.000000           NaN     7.000000
# 25%                 14.750000           NaN     9.000000
# 50%                 34.000000           NaN    11.000000
# 75%                 53.250000           NaN    13.000000
# max                138.000000           NaN    17.000000
#
# [8 rows x 157 columns]

# %%
list(jt)
# Out:
# ['Tour',
#  'Tournament Year',
#  'Tournament #',
#  'Permanent Tournament #',
#  'Course #',
#  'Team ID',
#  'Team Number',
#  'Player Number',
#  'Player Name',
#  'Round Number',
#  'Event Name',
#  'Course Name',
#  'Course Par',
#  'Course Yardage',
#  'Tee Time',
#  'Round Score',
#  'End of Round Finish Pos. (numeric)',
#  'End of Round Finish Pos. (text)',
#  ' End of Event Pos. (numeric)',
#  'End of Event Pos. (text)',
#  'In Playoff',
#  'Eagles',
#  'Eagles(Rank)',
#  'Birdies',
#  'Birdies (Rank)',
#  'Pars',
#  'Bogeys',
#  'Bogeys (Rank)',
#  'Doubles',
#  'Others',
#  'Total Holes Over Par',
#  ' Bogey Avoidance Rank',
#  'Longest Drive',
#  'Longest Drives(Rank)',
#  'Driving Distance(Total Distance)',
#  'Driving Distance(Total Drives)',
#  'Driving Distance(Rank)',
#  'Driving Dist. - All Drives(Tot. Dist.)',
#  'Driving Dist. - All Drives(# of Drives)',
#  'Driving Dist. - All Drives(Rank)',
#  'Drives Over 300 Yards (# of Drives)',
#  'Driving Acc. %(Fairways Hit)',
#  'Driving Acc. %(Possible Fairways)',
#  'Driving Accuracy Rank',
#  'Left Rough Tendency(Total Left Rough)',
#  'Right Rough Tendency(Total Right Rough)',
#  'App. 50-75 yds(ft)',
#  'App. 50-75 yds(attempts)',
#  'App. 75-100 yds(ft)',
#  'App. 75-100 yds(attempts)',
#  'App. 100-125 yds(ft)',
#  'App. 100-125 yds(attempts)',
#  'Approaches 50-125 Yards(ft)',
#  'Approaches 50-125 Yards(attempts)',
#  'Approaches 125-150 Yards(ft)',
#  'Approaches 125-150 Yards(attempts)',
#  'Approaches 150-175 Yards(ft)',
#  'Approaches 150-175 Yards(attempts)',
#  'Approaches 175-200 Yards(ft)',
#  'Approaches   175-200 Yards(attempts)',
#  'Approaches >200 Yards(ft)',
#  'Approaches >200 Yards(attempts)',
#  'App. 50-75 yds(ft) - Rough',
#  'App. 50-75 yds(attempts) - Rough',
#  'App. 75-100 yds(ft) - Rough',
#  'App. 75-100 yds(attempts) - Rough',
#  'App. 100-125 yds(ft) - Rough',
#  'App. 100-125 yds(attempts) - Rough',
#  'Approaches 50-125 Yards(ft) - Rough',
#  'Approaches 50-125 Yards(attempts) - Rough',
#  'Approaches 125-150 Yards(ft) - Rough',
#  'Approaches 125-150 Yards(attempts) - Rough',
#  'Approaches 150-175 Yards(ft) - Rough',
#  'Approaches 150-175 Yards(attempts) - Rough',
#  'Approaches 175-200 Yards(ft) - Rough',
#  'Approaches 175-200 Yards(attempts) - Rough',
#  'Approaches >200 Yards(ft) - Rough',
#  'Approaches >200 Yards(attempts) - Rough',
#  'Total Holes Played',
#  'Total Greens in Regulation',
#  'GIR Rank',
#  'Total Distance(ft) Prox to Hole',
#  ' # of Attempts Prox to Hole',
#  'Proximity to Hole (Rank)',
#  'Fairway Prox(attempts)',
#  'Fairway Prox(distance in ft)',
#  'Fairway Prox (Rank)',
#  'Rough Prox(attempts)',
#  'Rough Prox(distance in ft)',
#  'Rough Prox (Rank)',
#  'Left Rough Prox(attempts)',
#  'Left Rough Prox(distance in ft)',
#  'Right Rough Prox(attempts)',
#  'Right Rough Prox(distance in ft)',
#  'Going for Green(attempts)',
#  'Going for Green(non-attempts)',
#  'Going for the Green(successes)',
#  'Scrambling Par or Better',
#  'Scrambling Missed GIR',
#  'Scrambling (Rank)',
#  'Scrambling Proximity (Total Distance)',
#  'Scrambling Proximity (# of shots)',
#  'Scrambling Proximity (rank)',
#  'Scrambling from the Rough(successes)',
#  'Scrambling from the Rough(attempts)',
#  'Scrambling from the Fringe(successes)',
#  'Scrambling from the Fringe(attempts)',
#  'Scrambling >30 Yards(successes)',
#  ' Scrambling >30 Yards(attempts)',
#  'Scrambling   20-30 Yards(successes)',
#  ' Scrambling 20-30 Yards(attempts)',
#  'Scrambling 10-20 Yards(successes)',
#  ' Scrambling 10-20 Yards(attempts)',
#  'Scrambling < 10 Yards(successes)',
#  ' Scrambling < 10 Yards(attempts)',
#  'Sand Save %(# Saves)',
#  'Sand Save %(# Bunkers)',
#  'Sand Save (Rank)',
#  'Prox to Hole from Sand(Total Distance)',
#  ' Prox to Hole from Sand(# of Shots)',
#  'Total Hole Outs',
#  'Longest Hole Out(yards)',
#  'Overall Putting Avg(# of Putts)',
#  ' Putting Avg(GIR Putts)',
#  'One-Putt %(# of One Putts)',
#  '3-Putt Avoid(Total 3 Putts)',
#  'Approach Putt Performance(attempts)',
#  'Approach Putt Performance(ft))',
#  'Avg Distance of Putts Made(Total Distance of Putts)',
#  "Putting   3'(attempts)",
#  "Putting   3'(putts made)",
#  "Putting   4'(attempts)",
#  "Putting 4'(putts made)",
#  "Putting 5'(attempts)",
#  "Putting 5'(putts made)",
#  "Putting 6'(attempts)",
#  "Putting 6'(putts made)",
#  "Putting 7'(attempts)",
#  "Putting 7'(putts made)",
#  "Putting 8'(attempts)",
#  "Putting 8'(putts made)",
#  "Putting   9'(attempts)",
#  "Putting 9'(putts made)",
#  "Putting 10'(attempts)",
#  "Putting 10'(putts made)",
#  "Putting Inside 5' (putts made)",
#  "Putting Inside 5' (attempts)",
#  'Putting Inside 5 Feet (Rank)',
#  "Putting 5' - 10' (putts made)",
#  "Putting 5' - 10' (attempts)",
#  "Putting 5' - 10' (Rank)",
#  "Putting 4'-8'(attempts)",
#  "Putting 4'-8'(putts made)",
#  "Putting 4' - 8' (Rank)",
#  "Putting-Inside 10'(attempts)",
#  "Putting-Inside 10'(putts made)",
#  "Putting-Inside 10'(rank)",
#  "Putting 10'-15'(attempts)",
#  "Putting   10'-15'(putts made)",
#  "Putting 10'-15'(rank)",
#  "Putting 15-20'(attempts)",
#  "Putting 15'-20'(putts made)",
#  "Putting 15'-20'(rank)",
#  "Putting 20'-25'(attempts)",
#  "Putting 20'-25'(putts made)",
#  "Putting 20'-25'(rank)",
#  "Putting >25'(attempts)",
#  "Putting   >25'(putts made)",
#  "Putting   >25'(rank)",
#  "Putting   > 10' (putts made)",
#  "Putting   > 10' (attempts)",
#  "Putting   > 10' (rank)",
#  'Total Putts Gained',
#  'Total SG T2G',
#  'Total SG Total',
#  'OTT SG Avg.',
#  'APP SG Avg.',
#  'ARG SG Avg.',
#  'Unnamed: 178',
#  'TeeTimeHour']
