# %%
import pandas as pd

# %%
jt2016 = pd.read_csv('rround-2016.txt', sep=';', low_memory=False, encoding='latin-1',
                       usecols=['Tournament Year', 'Tournament #', 'Event Name', 'Player Name', 'Round Number', 
                                'Course Name', 'Course Par', 'Course Yardage', 'Tee Time',
                                'Round Score', 'App. 50-75 yds(ft)', 'App. 50-75 yds(attempts)', 
                                'App. 75-100 yds(ft)', 'App. 75-100 yds(attempts)', 
                                'App. 100-125 yds(ft)', 'App. 100-125 yds(attempts)', 
                                'Approaches 50-125 Yards(ft)', 'Approaches 50-125 Yards(attempts)', 
                                'Approaches 125-150 Yards(ft)', 'Approaches 125-150 Yards(attempts)', 
                                'Approaches 150-175 Yards(ft)', 'Approaches 150-175 Yards(attempts)', 
                                'Approaches 175-200 Yards(ft)', 'Approaches   175-200 Yards(attempts)', 
                                'Approaches >200 Yards(ft)', 'Approaches >200 Yards(attempts)', 
                                'App. 50-75 yds(ft) - Rough', 'App. 50-75 yds(attempts) - Rough', 
                                'App. 75-100 yds(ft) - Rough', 'App. 75-100 yds(attempts) - Rough', 
                                'App. 100-125 yds(ft) - Rough', 'App. 100-125 yds(attempts) - Rough', 
                                'Approaches 50-125 Yards(ft) - Rough', 'Approaches 50-125 Yards(attempts) - Rough', 
                                'Approaches 125-150 Yards(ft) - Rough', 'Approaches 125-150 Yards(attempts) - Rough', 
                                'Approaches 150-175 Yards(ft) - Rough', 'Approaches 150-175 Yards(attempts) - Rough', 
                                'Approaches 175-200 Yards(ft) - Rough', 'Approaches 175-200 Yards(attempts) - Rough', 
                                'Approaches >200 Yards(ft) - Rough', 'Approaches >200 Yards(attempts) - Rough', 
                                'Total Holes Played'])

jt2017 = pd.read_csv('rround-2017.txt', sep=';', low_memory=False, encoding='latin-1',
                       usecols=['Tournament Year', 'Tournament #', 'Event Name', 'Player Name', 'Round Number', 
                                'Course Name', 'Course Par', 'Course Yardage', 'Tee Time',
                                'Round Score', 'App. 50-75 yds(ft)', 'App. 50-75 yds(attempts)', 
                                'App. 75-100 yds(ft)', 'App. 75-100 yds(attempts)', 
                                'App. 100-125 yds(ft)', 'App. 100-125 yds(attempts)', 
                                'Approaches 50-125 Yards(ft)', 'Approaches 50-125 Yards(attempts)', 
                                'Approaches 125-150 Yards(ft)', 'Approaches 125-150 Yards(attempts)', 
                                'Approaches 150-175 Yards(ft)', 'Approaches 150-175 Yards(attempts)', 
                                'Approaches 175-200 Yards(ft)', 'Approaches   175-200 Yards(attempts)', 
                                'Approaches >200 Yards(ft)', 'Approaches >200 Yards(attempts)', 
                                'App. 50-75 yds(ft) - Rough', 'App. 50-75 yds(attempts) - Rough', 
                                'App. 75-100 yds(ft) - Rough', 'App. 75-100 yds(attempts) - Rough', 
                                'App. 100-125 yds(ft) - Rough', 'App. 100-125 yds(attempts) - Rough', 
                                'Approaches 50-125 Yards(ft) - Rough', 'Approaches 50-125 Yards(attempts) - Rough', 
                                'Approaches 125-150 Yards(ft) - Rough', 'Approaches 125-150 Yards(attempts) - Rough', 
                                'Approaches 150-175 Yards(ft) - Rough', 'Approaches 150-175 Yards(attempts) - Rough', 
                                'Approaches 175-200 Yards(ft) - Rough', 'Approaches 175-200 Yards(attempts) - Rough', 
                                'Approaches >200 Yards(ft) - Rough', 'Approaches >200 Yards(attempts) - Rough', 
                                'Total Holes Played'])

field2017 = pd.read_csv('rround-2017.txt', sep=';', low_memory=False, encoding='latin-1',
                       usecols=['Tournament Year', 'Tournament #', 'Event Name', 'Player Name', 'Round Number', 
                                'Course Name', 'Course Par', 'Course Yardage', 'Tee Time',
                                'Round Score', 'App. 50-75 yds(ft)', 'App. 50-75 yds(attempts)', 
                                'App. 75-100 yds(ft)', 'App. 75-100 yds(attempts)', 
                                'App. 100-125 yds(ft)', 'App. 100-125 yds(attempts)', 
                                'Approaches 50-125 Yards(ft)', 'Approaches 50-125 Yards(attempts)', 
                                'Approaches 125-150 Yards(ft)', 'Approaches 125-150 Yards(attempts)', 
                                'Approaches 150-175 Yards(ft)', 'Approaches 150-175 Yards(attempts)', 
                                'Approaches 175-200 Yards(ft)', 'Approaches   175-200 Yards(attempts)', 
                                'Approaches >200 Yards(ft)', 'Approaches >200 Yards(attempts)', 
                                'App. 50-75 yds(ft) - Rough', 'App. 50-75 yds(attempts) - Rough', 
                                'App. 75-100 yds(ft) - Rough', 'App. 75-100 yds(attempts) - Rough', 
                                'App. 100-125 yds(ft) - Rough', 'App. 100-125 yds(attempts) - Rough', 
                                'Approaches 50-125 Yards(ft) - Rough', 'Approaches 50-125 Yards(attempts) - Rough', 
                                'Approaches 125-150 Yards(ft) - Rough', 'Approaches 125-150 Yards(attempts) - Rough', 
                                'Approaches 150-175 Yards(ft) - Rough', 'Approaches 150-175 Yards(attempts) - Rough', 
                                'Approaches 175-200 Yards(ft) - Rough', 'Approaches 175-200 Yards(attempts) - Rough', 
                                'Approaches >200 Yards(ft) - Rough', 'Approaches >200 Yards(attempts) - Rough', 
                                'Total Holes Played'])

jt2017 = jt2017.loc[(jt2017['Player Name'] == 'Thomas, Justin')]
jt2016 = jt2016.loc[(jt2016['Player Name'] == 'Thomas, Justin')]
field2017 = field2017.loc[(field2017['Player Name'] != 'Thomas, Justin')]

# %%
jt = pd.concat([jt2016, jt2017])
jt.describe()
# Out:
#        Tournament Year  Tournament #  Round Number  Course Par  \
# count       185.000000    185.000000    185.000000  185.000000
# mean       2016.464865    270.324324      2.345946   71.135135
# std           0.500117    155.482778      1.103008    0.895707
# min        2016.000000     10.000000      1.000000   70.000000
# 25%        2016.000000    160.000000      1.000000   70.000000
# 50%        2016.000000    280.000000      2.000000   71.000000
# 75%        2017.000000    420.000000      3.000000   72.000000
# max        2017.000000    500.000000      4.000000   73.000000
#
#        Course Yardage  Round Score  App. 50-75 yds(ft)  \
# count      185.000000   185.000000           32.000000
# mean      7290.772973    69.675676           16.460969
# std        189.898549     4.828888           13.095805
# min       6841.000000    36.000000            1.250000
# 25%       7166.000000    67.000000            8.125250
# 50%       7322.000000    70.000000           13.333000
# ...

# %%
jtApproach2017 = []
jtApproach2017.append(jt2017['Approaches 50-125 Yards(ft)'].sum() / jt2017['Approaches 50-125 Yards(attempts)'].sum())
jtApproach2017.append(jt2017['Approaches 125-150 Yards(ft)'].sum() / jt2017['Approaches 125-150 Yards(attempts)'].sum())
jtApproach2017.append(jt2017['Approaches 150-175 Yards(ft)'].sum() / jt2017['Approaches 150-175 Yards(attempts)'].sum())
jtApproach2017.append(jt2017['Approaches 175-200 Yards(ft)'].sum() / jt2017['Approaches   175-200 Yards(attempts)'].sum())
jtApproach2017.append(jt2017['Approaches >200 Yards(ft)'].sum() / jt2017['Approaches >200 Yards(attempts)'].sum())
print(jtApproach2017)
# Out:
# [15.526807909604521, 21.787743589743584, 25.195377483443707, 33.11666206896552, 46.8673717277487]

# %%
jtRough2017 = []
jtRough2017.append(jt2017['Approaches 50-125 Yards(ft) - Rough'].sum() / jt2017['Approaches 50-125 Yards(attempts) - Rough'].sum())
jtRough2017.append(jt2017['Approaches 125-150 Yards(ft) - Rough'].sum() / jt2017['Approaches 125-150 Yards(attempts) - Rough'].sum())
jtRough2017.append(jt2017['Approaches 150-175 Yards(ft) - Rough'].sum() / jt2017['Approaches 150-175 Yards(attempts) - Rough'].sum())
jtRough2017.append(jt2017['Approaches 175-200 Yards(ft) - Rough'].sum() / jt2017['Approaches 175-200 Yards(attempts) - Rough'].sum())
jtRough2017.append(jt2017['Approaches >200 Yards(ft) - Rough'].sum() / jt2017['Approaches >200 Yards(attempts) - Rough'].sum())
print(jtRough2017)
# Out:
# [22.189142857142855, 36.55754545454547, 43.225586206896544, 47.07535483870967, 68.3163409090909]

# %%
jtApproach2016 = []
jtApproach2016.append(jt2016['Approaches 50-125 Yards(ft)'].sum() / jt2016['Approaches 50-125 Yards(attempts)'].sum())
jtApproach2016.append(jt2016['Approaches 125-150 Yards(ft)'].sum() / jt2016['Approaches 125-150 Yards(attempts)'].sum())
jtApproach2016.append(jt2016['Approaches 150-175 Yards(ft)'].sum() / jt2016['Approaches 150-175 Yards(attempts)'].sum())
jtApproach2016.append(jt2016['Approaches 175-200 Yards(ft)'].sum() / jt2016['Approaches   175-200 Yards(attempts)'].sum())
jtApproach2016.append(jt2016['Approaches >200 Yards(ft)'].sum() / jt2016['Approaches >200 Yards(attempts)'].sum())
print(jtApproach2016)
# Out:
# [18.26048167539267, 22.183330769230768, 24.792381502890176, 31.326881443298966, 44.42392270531403]

# %%
jtRough2016 = []
jtRough2016.append(jt2016['Approaches 50-125 Yards(ft) - Rough'].sum() / jt2016['Approaches 50-125 Yards(attempts) - Rough'].sum())
jtRough2016.append(jt2016['Approaches 125-150 Yards(ft) - Rough'].sum() / jt2016['Approaches 125-150 Yards(attempts) - Rough'].sum())
jtRough2016.append(jt2016['Approaches 150-175 Yards(ft) - Rough'].sum() / jt2016['Approaches 150-175 Yards(attempts) - Rough'].sum())
jtRough2016.append(jt2016['Approaches 175-200 Yards(ft) - Rough'].sum() / jt2016['Approaches 175-200 Yards(attempts) - Rough'].sum())
jtRough2016.append(jt2016['Approaches >200 Yards(ft) - Rough'].sum() / jt2016['Approaches >200 Yards(attempts) - Rough'].sum())
print(jtRough2016)
# Out:
# [27.660573170731713, 40.88890476190476, 41.34479999999999, 54.861051282051285, 78.21311475409836]

# %%
fieldApproach = []
fieldApproach.append(field2017['Approaches 50-125 Yards(ft)'].sum() / field2017['Approaches 50-125 Yards(attempts)'].sum())
fieldApproach.append(field2017['Approaches 125-150 Yards(ft)'].sum() / field2017['Approaches 125-150 Yards(attempts)'].sum())
fieldApproach.append(field2017['Approaches 150-175 Yards(ft)'].sum() / field2017['Approaches 150-175 Yards(attempts)'].sum())
fieldApproach.append(field2017['Approaches 175-200 Yards(ft)'].sum() / field2017['Approaches   175-200 Yards(attempts)'].sum())
fieldApproach.append(field2017['Approaches >200 Yards(ft)'].sum() / field2017['Approaches >200 Yards(attempts)'].sum())
print(fieldApproach)
# Out:
# [19.48349356199956, 23.428025188755058, 27.868796313408854, 33.81881572766857, 51.03813134601899]

# %%
fieldRough = []
fieldRough.append(field2017['Approaches 50-125 Yards(ft) - Rough'].sum() / field2017['Approaches 50-125 Yards(attempts) - Rough'].sum())
fieldRough.append(field2017['Approaches 125-150 Yards(ft) - Rough'].sum() / field2017['Approaches 125-150 Yards(attempts) - Rough'].sum())
fieldRough.append(field2017['Approaches 150-175 Yards(ft) - Rough'].sum() / field2017['Approaches 150-175 Yards(attempts) - Rough'].sum())
fieldRough.append(field2017['Approaches 175-200 Yards(ft) - Rough'].sum() / field2017['Approaches 175-200 Yards(attempts) - Rough'].sum())
fieldRough.append(field2017['Approaches >200 Yards(ft) - Rough'].sum() / field2017['Approaches >200 Yards(attempts) - Rough'].sum())
print(fieldRough)
# Out:
# [29.181435342692126, 36.751275103163636, 43.29302982545328, 53.03922418949634, 74.06047894161902]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['50-125 Yds', '125-150 Yds', '150-175 Yds', '175-200 Yds', '>200 Yds']
fig, (ax1, ax2) = plt.subplots(1,2)
# plt.ylim([min(values)-0.1, max(values)+0.1])
ax1.plot(jtApproach2017, label='Justin Thomas 2017')
ax1.plot(jtApproach2016, label='Justin Thomas 2016')
ax1.plot(fieldApproach, label='Field 2017')
ax1.set_title("All Approaches")
ax2.plot(jtRough2017, label='Justin Thomas 2017')
ax2.plot(jtRough2016, label='Justin Thomas 2016')
ax2.plot(fieldRough, label='Field 2017')
ax2.set_title("Approaches from Rough")

plt.legend()
plt.xticks(np.arange(5), ('50-125', '125-150', '150-175', '175-200', '>200'))
plt.show()

# %%
import pygal
from IPython.display import SVG, HTML

html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

# %%
chart = pygal.Bar()
chart.add('Justin Thomas 2017', jtApproach2017)
chart.add('Justin Thomas 2016', jtApproach2016)
chart.add('Field 2017', fieldApproach)
HTML(html_pygal.format(pygal_render=chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
# ...

# %%
chart = pygal.Funnel()
chart.x_labels = ['50-125 Yds', '125-150 Yds', '150-175 Yds', '175-200 Yds', '>200 Yds']
chart.add('Justin Thomas 2017', jtApproach2017)
chart.add('Justin Thomas 2016', jtApproach2016)
chart.add('Field 2017', fieldApproach)
HTML(html_pygal.format(pygal_render=chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
# ...
