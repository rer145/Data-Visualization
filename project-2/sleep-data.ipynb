# %%
import csv
import pandas as pd

# %%
data = pd.read_csv("sleepdata.csv", usecols=["Start", "End", "Sleep quality", "Time in bed", "Wake up", "Activity (steps)"])
data.head()
# Out:
#                  Start                  End Sleep quality Time in bed Wake up  \
# 0  2015-01-21 01:49:46  2015-01-21 07:20:03           65%        5:30     NaN
# 1  2015-01-21 23:55:29  2015-01-22 06:15:18           73%        6:19     NaN
# 2  2015-01-22 23:02:43  2015-01-23 06:12:41           81%        7:09     NaN
# 3  2015-01-25 22:48:04  2015-01-26 06:15:23           79%        7:27     NaN
# 4  2015-01-27 00:14:14  2015-01-27 06:14:29           56%        6:00     NaN
#
#    Activity (steps)
# 0              1112
# 1              1871
# 2              1010
# 3              2178
# 4              1440

# %%
#fixing data
data.fillna(":|", inplace=True)

for index, row in data.iterrows():
    data.set_value(index, 'Sleep quality', row["Sleep quality"].replace("%", ""))

# %%
data.head()
# Out:
#                  Start                  End Sleep quality Time in bed Wake up  \
# 0  2015-01-21 01:49:46  2015-01-21 07:20:03            65        5:30      :|
# 1  2015-01-21 23:55:29  2015-01-22 06:15:18            73        6:19      :|
# 2  2015-01-22 23:02:43  2015-01-23 06:12:41            81        7:09      :|
# 3  2015-01-25 22:48:04  2015-01-26 06:15:23            79        7:27      :|
# 4  2015-01-27 00:14:14  2015-01-27 06:14:29            56        6:00      :|
#
#    Activity (steps)
# 0              1112
# 1              1871
# 2              1010
# 3              2178
# 4              1440

# %%
data.tail()
# Out:
#                    Start                  End Sleep quality Time in bed  \
# 904  2017-10-06 23:06:04  2017-10-07 07:15:57            92        8:09
# 905  2017-10-07 23:08:00  2017-10-08 08:00:36            96        8:52
# 906  2017-10-08 23:31:29  2017-10-09 08:00:32           100        8:29
# 907  2017-10-10 00:02:33  2017-10-10 07:59:03            86        7:56
# 908  2017-10-10 23:19:36  2017-10-11 07:59:06           100        8:39
#
#     Wake up  Activity (steps)
# 904      :(              2083
# 905      :|              5793
# 906      :|              4236
# 907      :|              2885
# 908      :|              8798

# %%
#convert dates to actual dates
#convert numbers to numbers
data["Start"] = pd.to_datetime(data["Start"])
data["End"] = pd.to_datetime(data["End"])
data["Sleep quality"] = pd.to_numeric(data["Sleep quality"])
data["Activity (steps)"] = pd.to_numeric(data["Activity (steps)"])

# %%
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps)
# 0              1112
# 1              1871
# 2              1010
# 3              2178
# 4              1440

# %%
data.loc[(data["Start"] > '2015-01-01') & (data["Start"] <= '2015-02-01')]
# Out:
#                 Start                 End Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03            65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18            73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41            81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23            79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29            56        6:00      :|
# 5 2015-01-28 00:03:23 2015-01-28 06:15:40            65        6:12      :|
# 6 2015-01-28 23:38:34 2015-01-29 06:15:16            72        6:36      :|
# 7 2015-01-30 00:07:55 2015-01-30 06:08:24            66        6:00      :|
# 8 2015-01-31 22:41:35 2015-02-01 09:50:19            98       11:08      :|
#
#    Activity (steps)
# 0              1112
# 1              1871
# 2              1010
# 3              2178
# 4              1440
# 5              1985
# 6              1498
# 7              1459
# ...

# %%
# convert time in bed to minutes
data["Time in bed (minutes)"] = data["Time in bed"]
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps) Time in bed (minutes)
# 0              1112                  5:30
# 1              1871                  6:19
# 2              1010                  7:09
# 3              2178                  7:27
# 4              1440                  6:00

# %%
for index, row in data.iterrows():
    minutes = (int(row["Time in bed (minutes)"][0:row["Time in bed (minutes)"].index(":")])*60) + int(row["Time in bed (minutes)"][row["Time in bed (minutes)"].index(":")+1:]) 
    data.set_value(index, 'Time in bed (minutes)', minutes)

# %%
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps) Time in bed (minutes)
# 0              1112                   330
# 1              1871                   379
# 2              1010                   429
# 3              2178                   447
# 4              1440                   360

# %%
data["Time in bed (minutes)"] = pd.to_numeric(data["Time in bed (minutes)"])
data.describe()
# Out:
#        Sleep quality  Activity (steps)  Time in bed (minutes)
# count     909.000000        909.000000             909.000000
# mean       74.302530       5365.634763             435.633663
# std        15.732756       5044.821269              86.597994
# min         0.000000          0.000000               0.000000
# 25%        66.000000       1503.000000             395.000000
# 50%        75.000000       3116.000000             442.000000
# 75%        85.000000       8375.000000             484.000000
# max       100.000000      26687.000000             716.000000

# %%
data.sort_values("Time in bed (minutes)", ascending=True)
# Out:
#                   Start                 End  Sleep quality Time in bed  \
# 592 2016-10-30 23:38:51 2016-10-31 01:06:52              0        0:00
# 660 2017-01-12 21:54:53 2017-01-13 03:36:53              0        0:00
# 858 2017-08-18 22:56:38 2017-08-19 07:28:11              0        0:00
# 237 2015-10-19 23:07:56 2015-10-20 00:21:55              0        0:00
# 343 2016-02-10 05:32:15 2016-02-10 06:14:41              9        0:42
# 43  2015-03-15 23:11:20 2015-03-15 23:57:10             10        0:45
# 529 2016-08-28 23:12:28 2016-08-29 00:12:51             13        1:00
# 493 2016-07-17 03:41:00 2016-07-17 05:49:52             27        2:08
# 29  2015-02-26 04:01:44 2015-02-26 06:13:01             18        2:11
# 501 2016-07-27 03:43:49 2016-07-27 06:15:16             26        2:31
# 496 2016-07-20 00:41:36 2016-07-20 03:13:48             33        2:32
# 594 2016-11-02 03:27:19 2016-11-02 06:14:16             34        2:46
# ...

# %%
data = data.drop([592,660,858,237])
data.sort_values("Time in bed (minutes)", ascending=True)
# Out:
#                   Start                 End  Sleep quality Time in bed  \
# 343 2016-02-10 05:32:15 2016-02-10 06:14:41              9        0:42
# 43  2015-03-15 23:11:20 2015-03-15 23:57:10             10        0:45
# 529 2016-08-28 23:12:28 2016-08-29 00:12:51             13        1:00
# 493 2016-07-17 03:41:00 2016-07-17 05:49:52             27        2:08
# 29  2015-02-26 04:01:44 2015-02-26 06:13:01             18        2:11
# 501 2016-07-27 03:43:49 2016-07-27 06:15:16             26        2:31
# 496 2016-07-20 00:41:36 2016-07-20 03:13:48             33        2:32
# 594 2016-11-02 03:27:19 2016-11-02 06:14:16             34        2:46
# 83  2015-05-07 04:12:10 2015-05-07 07:00:04             33        2:47
# 51  2015-03-25 03:19:36 2015-03-25 06:15:23             26        2:55
# 370 2016-03-09 03:18:21 2016-03-09 06:13:59             38        2:55
# 19  2015-02-12 02:40:31 2015-02-12 06:04:22             39        3:23
# ...

# %%
data.describe()
# Out:
#        Sleep quality  Activity (steps)  Time in bed (minutes)
# count     905.000000        905.000000             905.000000
# mean       74.630939       5375.138122             437.559116
# std        14.969243       5052.107662              81.786084
# min         9.000000          0.000000              42.000000
# 25%        66.000000       1503.000000             396.000000
# 50%        75.000000       3125.000000             442.000000
# 75%        85.000000       8378.000000             484.000000
# max       100.000000      26687.000000             716.000000

# %%
data["Start Weekday"] = data["Start"].dt.dayofweek

# %%
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps)  Time in bed (minutes)  Start Weekday
# 0              1112                    330              2
# 1              1871                    379              2
# 2              1010                    429              3
# 3              2178                    447              6
# 4              1440                    360              1

# %%
data["Start Year"] = data["Start"].dt.year
data["Start Month"] = data["Start"].dt.month
data["Start Day"] = data["Start"].dt.day
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps)  Time in bed (minutes)  Start Weekday  Start Year  \
# 0              1112                    330              2        2015
# 1              1871                    379              2        2015
# 2              1010                    429              3        2015
# 3              2178                    447              6        2015
# 4              1440                    360              1        2015
#
#    Start Month  Start Day
# 0            1         21
# 1            1         21
# ...

# %%
data.groupby("Start Year").describe()
# Out:
#            Activity (steps)                                                   \
#                       count         mean          std   min      25%     50%
# Start Year
# 2015                  303.0  5660.376238  5326.131880   0.0  1378.50  3285.0
# 2016                  344.0  5384.508721  5219.179879   0.0  1528.00  2832.0
# 2017                  258.0  5027.655039  4457.917785  69.0  1597.25  3381.0
#
#                              Sleep quality             ...   Start Weekday  \
#                 75%      max         count       mean  ...             75%
# Start Year                                             ...
# 2015        8849.00  26687.0         303.0  76.128713  ...             5.0
# 2016        8391.25  26420.0         344.0  72.511628  ...             5.0
# 2017        7656.50  21622.0         258.0  75.697674  ...             5.0
#
#                 Time in bed (minutes)                                       \
# ...

# %%
# convert wake up into human readable strings
for index, row in data.iterrows():
    if (row["Wake up"] == ":)"):
        mood = "Good"
    elif (row["Wake up"] == ":("):
        mood = "Bad"
    else:
        mood = "Neutral"
    data.set_value(index, 'Mood', mood)

# %%
data.head()
# Out:
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0 2015-01-21 01:49:46 2015-01-21 07:20:03             65        5:30      :|
# 1 2015-01-21 23:55:29 2015-01-22 06:15:18             73        6:19      :|
# 2 2015-01-22 23:02:43 2015-01-23 06:12:41             81        7:09      :|
# 3 2015-01-25 22:48:04 2015-01-26 06:15:23             79        7:27      :|
# 4 2015-01-27 00:14:14 2015-01-27 06:14:29             56        6:00      :|
#
#    Activity (steps)  Time in bed (minutes)  Start Weekday  Start Year  \
# 0              1112                    330              2        2015
# 1              1871                    379              2        2015
# 2              1010                    429              3        2015
# 3              2178                    447              6        2015
# 4              1440                    360              1        2015
#
#    Start Month  Start Day     Mood
# 0            1         21  Neutral
# ...

# %%
data.describe()
# Out:
#        Sleep quality  Activity (steps)  Time in bed (minutes)  Start Weekday  \
# count     905.000000        905.000000             905.000000     905.000000
# mean       74.630939       5375.138122             437.559116       3.024309
# std        14.969243       5052.107662              81.786084       2.067304
# min         9.000000          0.000000              42.000000       0.000000
# 25%        66.000000       1503.000000             396.000000       1.000000
# 50%        75.000000       3125.000000             442.000000       3.000000
# 75%        85.000000       8378.000000             484.000000       5.000000
# max       100.000000      26687.000000             716.000000       6.000000
#
#         Start Year  Start Month   Start Day
# count   905.000000   905.000000  905.000000
# mean   2015.950276     6.283978   15.668508
# std       0.786193     3.238324    8.901411
# min    2015.000000     1.000000    1.000000
# 25%    2015.000000     4.000000    8.000000
# ...

# %%
data.groupby("Mood").describe()
# Out:
#         Activity (steps)                                                    \
#                    count         mean          std    min      25%     50%
# Mood
# Bad                 50.0  4920.060000  4064.152839   69.0  1928.50  3720.0
# Good                43.0  4910.511628  4846.449596  299.0  1300.00  2887.0
# Neutral            812.0  5427.764778  5119.505590    0.0  1508.25  3129.5
#
#                           Sleep quality             ...   Start Year          \
#              75%      max         count       mean  ...          75%     max
# Mood                                                ...
# Bad      7482.75  14521.0          50.0  67.300000  ...       2017.0  2017.0
# Good     7482.50  18278.0          43.0  81.837209  ...       2016.5  2017.0
# Neutral  8423.75  26687.0         812.0  74.700739  ...       2017.0  2017.0
#
#         Time in bed (minutes)                                               \
# ...

# %%
data.groupby("Start Weekday").describe()
# Out:
#               Activity (steps)                                            \
#                          count         mean          std    min      25%
# Start Weekday
# 0                        132.0  3950.037879  4046.947445    0.0  1350.25
# 1                        126.0  5177.515873  3997.515984  260.0  1880.00
# 2                        143.0  5364.160839  4719.260135  190.0  1651.50
# 3                        128.0  3840.710938  4138.507004   71.0  1431.50
# 4                        110.0  5168.936364  4824.540180  204.0  1195.25
# 5                         95.0  8288.557895  6424.685360  166.0  2828.00
# 6                        171.0  6292.666667  5763.123740   69.0  1109.50
#
#                                          Sleep quality             ...    \
#                   50%       75%      max         count       mean  ...
# Start Weekday                                                      ...
# 0              2548.0   4556.00  21034.0         132.0  75.666667  ...
# ...

# %%
data.groupby("Mood")["Sleep quality"].describe()
# Out:
#          count       mean        std   min    25%   50%   75%    max
# Mood
# Bad       50.0  67.300000  18.240178   9.0  56.75  68.0  78.5  100.0
# Good      43.0  81.837209  11.109692  55.0  74.00  81.0  91.0  100.0
# Neutral  812.0  74.700739  14.738003  10.0  66.00  75.0  85.0  100.0

# %%
data.groupby("Start Weekday")["Sleep quality"].describe()
# Out:
#                count       mean        std   min    25%   50%    75%    max
# Start Weekday
# 0              132.0  75.666667  12.534938  39.0  67.00  75.0  83.25  100.0
# 1              126.0  73.111111  14.277939  36.0  63.00  73.0  84.00  100.0
# 2              143.0  71.195804  18.022779   9.0  64.50  74.0  83.00  100.0
# 3              128.0  73.640625  14.192010  18.0  64.75  74.0  83.00  100.0
# 4              110.0  76.890909  14.058427  40.0  66.25  77.0  89.00  100.0
# 5               95.0  76.126316  14.726039  41.0  67.00  77.0  88.50  100.0
# 6              171.0  76.280702  15.220831  10.0  70.00  79.0  86.50  100.0

# %%
data.loc[(data["Start"] >= '2017-06-05') & (data["Start"] < '2017-08-23')]["Sleep quality"].describe()
# Out:
# count     75.000000
# mean      80.266667
# std       15.681228
# min       37.000000
# 25%       71.000000
# 50%       83.000000
# 75%       92.500000
# max      100.000000
# Name: Sleep quality, dtype: float64

# %%
data.loc[data["Start"] < '2017-06-05']["Sleep quality"].describe()
# Out:
# count    784.000000
# mean      73.792092
# std       14.762362
# min        9.000000
# 25%       66.000000
# 50%       75.000000
# 75%       84.000000
# max      100.000000
# Name: Sleep quality, dtype: float64

# %%
data.loc[data["Start"] >= '2017-08-23']["Sleep quality"].describe()
# Out:
# count     46.000000
# mean      79.739130
# std       14.605075
# min       31.000000
# 25%       72.000000
# 50%       78.000000
# 75%       92.750000
# max      100.000000
# Name: Sleep quality, dtype: float64

# %%
data.loc[data["Start"] >= '2017-01-01']
# Out:
#                   Start                 End  Sleep quality Time in bed  \
# 649 2017-01-01 23:31:04 2017-01-02 07:59:45             95        8:28
# 650 2017-01-02 23:29:42 2017-01-03 06:13:25             71        6:43
# 651 2017-01-03 23:57:28 2017-01-04 06:07:57             62        6:10
# 652 2017-01-04 23:26:43 2017-01-05 06:14:09             58        6:47
# 653 2017-01-05 19:29:10 2017-01-06 05:32:02             70       10:02
# 654 2017-01-06 23:21:33 2017-01-07 07:08:23             59        7:46
# 655 2017-01-08 00:04:37 2017-01-08 09:12:53             91        9:08
# 656 2017-01-08 21:38:16 2017-01-09 05:05:18             73        7:27
# 657 2017-01-10 00:33:14 2017-01-10 06:14:39             36        5:41
# 658 2017-01-10 22:02:47 2017-01-11 05:05:51             73        7:03
# 659 2017-01-11 23:02:08 2017-01-12 06:14:08             68        7:11
# 661 2017-01-15 00:04:04 2017-01-15 08:11:42             94        8:07
# ...

# %%
data.groupby("Start Year").describe()
# Out:
#            Activity (steps)                                                   \
#                       count         mean          std   min      25%     50%
# Start Year
# 2015                  303.0  5660.376238  5326.131880   0.0  1378.50  3285.0
# 2016                  344.0  5384.508721  5219.179879   0.0  1528.00  2832.0
# 2017                  258.0  5027.655039  4457.917785  69.0  1597.25  3381.0
#
#                              Sleep quality             ...   Start Weekday  \
#                 75%      max         count       mean  ...             75%
# Start Year                                             ...
# 2015        8849.00  26687.0         303.0  76.128713  ...             5.0
# 2016        8391.25  26420.0         344.0  72.511628  ...             5.0
# 2017        7656.50  21622.0         258.0  75.697674  ...             5.0
#
#                 Time in bed (minutes)                                       \
# ...

# %%
dataDayOfWeek = data.groupby("Start Weekday")

# %%
data.groupby("Start Month")["Sleep quality"].mean()
# Out:
# Start Month
# 1     72.492308
# 2     71.506667
# 3     72.588235
# 4     74.740260
# 5     70.694118
# 6     76.261905
# 7     80.109890
# 8     75.380952
# 9     77.666667
# 10    79.357143
# 11    69.259259
# 12    72.555556
# Name: Sleep quality, dtype: float64

# %%
data.groupby("Mood").describe()
# Out:
#         Activity (steps)                                                    \
#                    count         mean          std    min      25%     50%
# Mood
# Bad                 50.0  4920.060000  4064.152839   69.0  1928.50  3720.0
# Good                43.0  4910.511628  4846.449596  299.0  1300.00  2887.0
# Neutral            812.0  5427.764778  5119.505590    0.0  1508.25  3129.5
#
#                           Sleep quality             ...   Start Year          \
#              75%      max         count       mean  ...          75%     max
# Mood                                                ...
# Bad      7482.75  14521.0          50.0  67.300000  ...       2017.0  2017.0
# Good     7482.50  18278.0          43.0  81.837209  ...       2016.5  2017.0
# Neutral  8423.75  26687.0         812.0  74.700739  ...       2017.0  2017.0
#
#         Time in bed (minutes)                                               \
# ...

# %%
data.loc[data["Mood"] == "Good"].count()
# Out:
# Start                    43
# End                      43
# Sleep quality            43
# Time in bed              43
# Wake up                  43
# Activity (steps)         43
# Time in bed (minutes)    43
# Start Weekday            43
# Start Year               43
# Start Month              43
# Start Day                43
# Mood                     43
# dtype: int64

# %%
data.groupby("Start Weekday")["Time in bed (minutes)"].mean()
# Out:
# Start Weekday
# 0    447.189394
# 1    430.793651
# 2    416.671329
# 3    433.328125
# 4    448.209091
# 5    442.305263
# 6    446.257310
# Name: Time in bed (minutes), dtype: float64

# %%
data.loc[data["Start Weekday"] == 0]["Sleep quality"].mean()
# Out:
# 75.66666666666667
